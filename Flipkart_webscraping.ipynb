# %%
import numpy as np
import pandas as pd
import datetime
import requests
from bs4 import BeautifulSoup

# %%
URL = 'https://www.flipkart.com/realme-7-mist-blue-64-gb/product-reviews/itme55d08631f19b?pid=MOBFUYUNMB7CUZH3&lid=LSTMOBFUYUNMB7CUZH3KH1SPJ&marketplace=FLIPKART'

# %%
a = []
b= []
c = []
d = []
e = []
f = []
g = []
h = []
ia = []
j = []
k = []
l = []
m = []
z = []
fe = []

# %%
feature = []
url = 'https://www.flipkart.com/search?q=real%20me%206&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
page = requests.get(url)
htmlcode = page.text
soup = BeautifulSoup(htmlcode)
name = soup.find('div', attrs={'class' : 'col col-7-12'})
feature.append(name.text)

# %%
feature = ['6 GB RAM | 64 GB ROM | Expandable Upto 256 GB16.51 cm (6.5 inch) Full HD+ Display48MP + 8MP + 2MP + 2MP | 16MP Front Camera4500 mAh Lithium-ion BatteryMediaTek Helio G95 Processor65W Super Dart ChargerBrand Warranty of 1 Year Available for Mobile and 6 Months for Accessories']

# %%
import re

# %%
regex = ('')
feature = re.compile(regex).findall(feature)

# %%
for i in range(1, 1000):
    URL = 'https://www.flipkart.com/realme-6-comet-blue-64-gb/product-reviews/itma64226eb3e2d2?pid=MOBFTAZ5CXWPRYKW&lid=LSTMOBFTAZ5CXWPRYKWQYRGQK&marketplace=FLIPKART&page={}'. format(i)
    
    page = requests.get(URL)
    htmlCode = page.text
    print(i,page)
    
    soup = BeautifulSoup(htmlCode)
    
    for x in soup.find_all('div', attrs={'class' : '_27M-vq'}):
        

        name = x.find('div', attrs={'class' : '_3LWZlK _1BLPMq'})
        
        if name is None:
            
            a.append(np.NaN)
        else:
            a.append(name.text)
            
        ratename = x.find('p', attrs={'class' : '_2-N8zT'})
                                      
        if ratename is None:
                                      
            b.append(np.NaN)
        else:
            b.append(ratename.text)

        review = x.find('div', attrs={'class' : 't-ZTKy'})
                                      
        if review is None:
            c.append(np.NaN)
        else:
            c.append(review.text)

        months = x.find('div', attrs={'class' : 'row _3n8db9'})
                                      
        if months is None:
            d.append(np.NaN)
        else:
            d.append(months.text)
        likes = x.find('span', attrs={'class' : '_3c3Px5'})
        if likes is None:
            e.append(np.NaN)
        else:
            e.append(likes.text)
        dislikes = x.find('span', attrs={'class':'_3c3Px5'})
        
        if dislikes is None:
            f.append(np.NaN)
        else:
            f.append(dislikes.text)
        
        city = x.find('p', attrs={'class':'_2mcZGG'})
        
        if city is None:
            g.append(np.NaN)
        else:
            g.append(city.text)
            
            h.append('Realme ')
            k.append('Realme 6')
            l.append('4.4')
            ia.append('14999')
            z.append('mobile')
            fe.append(feature)
# Out:
# 1 <Response [200]>
# 2 <Response [200]>
# 3 <Response [200]>
# 4 <Response [200]>
# 5 <Response [200]>
# 6 <Response [200]>
# 7 <Response [200]>
# 8 <Response [200]>
# 9 <Response [200]>
# 10 <Response [200]>
# 11 <Response [200]>
# 12 <Response [200]>
# 13 <Response [200]>
# 14 <Response [200]>
# 15 <Response [200]>
# 16 <Response [200]>
# 17 <Response [200]>
# 18 <Response [200]>
# 19 <Response [200]>
# 20 <Response [200]>
# 21 <Response [200]>
# 22 <Response [200]>
# 23 <Response [200]>
# 24 <Response [200]>
# 25 <Response [200]>
# 26 <Response [200]>
# 27 <Response [200]>
# 28 <Response [200]>
# 29 <Response [200]>
# 30 <Response [200]>
# 31 <Response [200]>
# 32 <Response [200]>
# 33 <Response [200]>
# 34 <Response [200]>
# 35 <Response [200]>
# 36 <Response [200]>
# 37 <Response [200]>
# 38 <Response [200]>
# 39 <Response [200]>
# 40 <Response [200]>
# 41 <Response [200]>
# 42 <Response [200]>
# 43 <Response [200]>
# 44 <Response [200]>
# 45 <Response [200]>
# ...

# %%
len(a)
# Out:
# 9886

# %%
len(b)
# Out:
# 9886

# %%
len(h)
# Out:
# 9886

# %%
df1 = pd.DataFrame({'product_brand':h, 'product_name':k, 'product_category':z,'product_price':ia,'product_features':fe,'Avg_Rating':l, 'Review_Title' : b,'Review_text' : c,'Rating' : a,'customer_city':g,'age_of_review' : d,'review_upvotes':e,'review_downvotes':f})

# %%
df1
# Out:
#      product_brand product_name product_category product_price  \
# 0          Realme      Realme 6           mobile         14999
# 1          Realme      Realme 6           mobile         14999
# 2          Realme      Realme 6           mobile         14999
# 3          Realme      Realme 6           mobile         14999
# 4          Realme      Realme 6           mobile         14999
# ...            ...          ...              ...           ...
# 9881       Realme      Realme 6           mobile         14999
# 9882       Realme      Realme 6           mobile         14999
# 9883       Realme      Realme 6           mobile         14999
# 9884       Realme      Realme 6           mobile         14999
# 9885       Realme      Realme 6           mobile         14999
#
#                                        product_features Avg_Rating  \
# 0     [6 GB RAM | 64 GB ROM | Expandable Upto 256 GB...        4.4
# 1     [6 GB RAM | 64 GB ROM | Expandable Upto 256 GB...        4.4
# ...

# %%
import re

# %%
def check(x):
    if type(x)==float:
        return np.NaN
    else:
        x=x.lower()
        x=re.findall('\w',x)
        x=''.join(x)
        r = re.findall("(\d+[month|months|day|days]+ago)", x)
        if r!=[]:
            return r[0]
        r = re.findall("today", x)
        if r!=[]:
            return r[0]
        r = re.findall("[jan|january|feb|february|mar|march|apr|april|may|jun|june|july|aug|august|sep|september|oct|october|nov|november|dec|december]+\d\d\d\d", x)
        if r!=[]:
            return r[0][len(r[0])-7:len(r[0])]

# %%
df1['age_of_review']=df1['age_of_review'].apply(check)

# %%
df1['age_of_review'].value_counts()
# Out:
# 3monthsago     2832
# 1monthago      1815
# 2monthsago     1414
# 4monthsago     1145
# 5monthsago      918
# 6monthsago      203
# 7monthsago      149
# 8monthsago      128
# 11monthsago     112
# 26daysago        99
# 25daysago        72
# 9monthsago       67
# 23daysago        60
# 24daysago        59
# 10monthsago      55
# 27daysago        54
# 18daysago        53
# 29daysago        49
# 16daysago        46
# 30daysago        40
# 17daysago        38
# 21daysago        34
# 2daysago         32
# today            30
# 12daysago        29
# 15daysago        29
# 28daysago        27
# 13daysago        27
# 10daysago        25
# 19daysago        25
# 6daysago         24
# 1dayago          23
# 22daysago        22
# 11daysago        22
# 3daysago         21
# 20daysago        20
# 8daysago         19
# 7daysago         17
# 4daysago         17
# 9daysago         15
# 5daysago          9
# 14daysago         7
# 13monthsago       1
# 23monthsago       1
# 73monthsago       1
# ...

# %%
df1
# Out:
#      product_brand product_name product_category product_price  \
# 0          Realme      Realme 6           mobile         14999
# 1          Realme      Realme 6           mobile         14999
# 2          Realme      Realme 6           mobile         14999
# 3          Realme      Realme 6           mobile         14999
# 4          Realme      Realme 6           mobile         14999
# ...            ...          ...              ...           ...
# 9881       Realme      Realme 6           mobile         14999
# 9882       Realme      Realme 6           mobile         14999
# 9883       Realme      Realme 6           mobile         14999
# 9884       Realme      Realme 6           mobile         14999
# 9885       Realme      Realme 6           mobile         14999
#
#                                        product_features Avg_Rating  \
# 0     [6 GB RAM | 64 GB ROM | Expandable Upto 256 GB...        4.4
# 1     [6 GB RAM | 64 GB ROM | Expandable Upto 256 GB...        4.4
# ...

# %%
regex = ('[^,]*$')
df1['customer_city']=df1['customer_city'].apply(lambda x : re.compile(regex).findall(x))

# %%
df1.customer_city=df1.customer_city.apply(lambda x:str(x).replace('[','').replace(']',''))

# %%
df1.customer_city=df1.customer_city.apply(lambda x:str(x).replace("'",'').replace("'",''))

# %%
df1.customer_city=df1.customer_city.apply(lambda x:str(x).replace(',',''))

# %%
df1
# Out:
#      product_brand product_name product_category product_price  \
# 0          Realme      Realme 6           mobile         14999
# 1          Realme      Realme 6           mobile         14999
# 2          Realme      Realme 6           mobile         14999
# 3          Realme      Realme 6           mobile         14999
# 4          Realme      Realme 6           mobile         14999
# ...            ...          ...              ...           ...
# 9881       Realme      Realme 6           mobile         14999
# 9882       Realme      Realme 6           mobile         14999
# 9883       Realme      Realme 6           mobile         14999
# 9884       Realme      Realme 6           mobile         14999
# 9885       Realme      Realme 6           mobile         14999
#
#                                        product_features Avg_Rating  \
# 0     [6 GB RAM | 64 GB ROM | Expandable Upto 256 GB...        4.4
# 1     [6 GB RAM | 64 GB ROM | Expandable Upto 256 GB...        4.4
# ...

# %%
df1.to_csv(r'realme6.csv',index=False)

# %%
a = []
b= []
c = []
d = []
e = []
f = []
g = []
h = []
ia =[]
j = []
k = []
l = []
m = []
z = []
fe = []

# %%
feature = []
url = 'https://www.flipkart.com/search?q=samsung+guru+1200&otracker=AS_Query_HistoryAutoSuggest_3_0&otracker1=AS_Query_HistoryAutoSuggest_3_0&marketplace=FLIPKART&as-show=off&as=off&as-pos=3&as-type=HISTORY'
page = requests.get(url)
htmlcode = page.text
soup = BeautifulSoup(htmlcode)
name = soup.find('div', attrs={'class' : 'fMghEO'})
feature.append(name.text)

# %%
feature
# Out:
# ['NA ROM3.81 cm (1.5 inch) NA Display800 mAh Battery0 0 0 0 Processor Processor1 Year for Mobile & 6 Months for Accessories']

# %%
for i in range(1, 1350):
    URL = 'https://www.flipkart.com/samsung-guru-1200/product-reviews/itmeb6w98vmhffjy?pid=MOBDA2CFCQ6CFHTZ&lid=LSTMOBDA2CFCQ6CFHTZKLVHX9&marketplace=FLIPKART&page={}'. format(i)
    
    page = requests.get(URL)
    htmlCode = page.text
    print(i,page)
    
    soup = BeautifulSoup(htmlCode)
    
    for x in soup.find_all('div', attrs={'class' : '_27M-vq'}):
        

        name = x.find('div', attrs={'class' : '_3LWZlK _1BLPMq'})
        
        if name is None:
            
            a.append(np.NaN)
        else:
            a.append(name.text)
            
        ratename = x.find('p', attrs={'class' : '_2-N8zT'})
                                      
        if ratename is None:
                                      
            b.append(np.NaN)
        else:
            b.append(ratename.text)

        review = x.find('div', attrs={'class' : 't-ZTKy'})
                                      
        if review is None:
            c.append(np.NaN)
        else:
            c.append(review.text)

        months = x.find('div', attrs={'class' : 'row _3n8db9'})
                                      
        if months is None:
            d.append(np.NaN)
        else:
            d.append(months.text)
        likes = x.find('span', attrs={'class' : '_3c3Px5'})
        if likes is None:
            e.append(np.NaN)
        else:
            e.append(likes.text)
        dislikes = x.find('span', attrs={'class':'_3c3Px5'})
        
        if dislikes is None:
            f.append(np.NaN)
        else:
            f.append(dislikes.text)
        
        city = x.find('p', attrs={'class':'_2mcZGG'})
        
        if city is None:
            g.append(np.NaN)
        else:
            g.append(city.text)
        h.append('samsung')
        j.append('Phone')
        k.append('samsung guru 1200')
        l.append('4.3')
        ia.append('1334')
        z.append('mobile')
        fe.append(feature)
# Out:
# 1 <Response [200]>
# 2 <Response [200]>
# 3 <Response [200]>
# 4 <Response [200]>
# 5 <Response [200]>
# 6 <Response [200]>
# 7 <Response [200]>
# 8 <Response [200]>
# 9 <Response [200]>
# 10 <Response [200]>
# 11 <Response [200]>
# 12 <Response [200]>
# 13 <Response [200]>
# 14 <Response [200]>
# 15 <Response [200]>
# 16 <Response [200]>
# 17 <Response [200]>
# 18 <Response [200]>
# 19 <Response [200]>
# 20 <Response [200]>
# 21 <Response [200]>
# 22 <Response [200]>
# 23 <Response [200]>
# 24 <Response [200]>
# 25 <Response [200]>
# 26 <Response [200]>
# 27 <Response [200]>
# 28 <Response [200]>
# 29 <Response [200]>
# 30 <Response [200]>
# 31 <Response [200]>
# 32 <Response [200]>
# 33 <Response [200]>
# 34 <Response [200]>
# 35 <Response [200]>
# 36 <Response [200]>
# 37 <Response [200]>
# 38 <Response [200]>
# 39 <Response [200]>
# 40 <Response [200]>
# 41 <Response [200]>
# 42 <Response [200]>
# 43 <Response [200]>
# 44 <Response [200]>
# 45 <Response [200]>
# ...

# %%
len(a)
# Out:
# 9990

# %%
len(b)
# Out:
# 9990

# %%
len(ia)
# Out:
# 9990

# %%
df2 = pd.DataFrame({'product_brand':h, 'product_name':k, 'product_category':z,'product_price':ia,'product_features':fe,'Avg_Rating':l, 'Review_Title' : b,'Review_text' : c,'Rating' : a,'customer_city':g,'age_of_review' : d,'review_upvotes':e,'review_downvotes':f})

# %%
df2
# Out:
#      product_brand       product_name product_category product_price  \
# 0          samsung  samsung guru 1200           mobile          1334
# 1          samsung  samsung guru 1200           mobile          1334
# 2          samsung  samsung guru 1200           mobile          1334
# 3          samsung  samsung guru 1200           mobile          1334
# 4          samsung  samsung guru 1200           mobile          1334
# ...            ...                ...              ...           ...
# 9985       samsung  samsung guru 1200           mobile          1334
# 9986       samsung  samsung guru 1200           mobile          1334
# 9987       samsung  samsung guru 1200           mobile          1334
# 9988       samsung  samsung guru 1200           mobile          1334
# 9989       samsung  samsung guru 1200           mobile          1334
#
#                                        product_features Avg_Rating  \
# 0     [NA ROM3.81 cm (1.5 inch) NA Display800 mAh Ba...        4.3
# ...

# %%
import re

# %%
def check(x):
    if type(x)==float:
        return np.NaN
    else:
        x=x.lower()
        x=re.findall('\w',x)
        x=''.join(x)
        r = re.findall("(\d+[month|months|day|days]+ago)", x)
        if r!=[]:
            return r[0]
        r = re.findall("today", x)
        if r!=[]:
            return r[0]
        r = re.findall("[jan|january|feb|february|mar|march|apr|april|may|jun|june|july|aug|august|sep|september|oct|october|nov|november|dec|december]+\d\d\d\d", x)
        if r!=[]:
            return r[0][len(r[0])-7:len(r[0])]

# %%
df2['age_of_review']=df2['age_of_review'].apply(check)

# %%
df2
# Out:
#      product_brand       product_name product_category product_price  \
# 0          samsung  samsung guru 1200           mobile          1334
# 1          samsung  samsung guru 1200           mobile          1334
# 2          samsung  samsung guru 1200           mobile          1334
# 3          samsung  samsung guru 1200           mobile          1334
# 4          samsung  samsung guru 1200           mobile          1334
# ...            ...                ...              ...           ...
# 9985       samsung  samsung guru 1200           mobile          1334
# 9986       samsung  samsung guru 1200           mobile          1334
# 9987       samsung  samsung guru 1200           mobile          1334
# 9988       samsung  samsung guru 1200           mobile          1334
# 9989       samsung  samsung guru 1200           mobile          1334
#
#                                        product_features Avg_Rating  \
# 0     [NA ROM3.81 cm (1.5 inch) NA Display800 mAh Ba...        4.3
# ...

# %%
df2.dtypes
# Out:
# product_brand       object
# product_name        object
# product_category    object
# product_price       object
# product_features    object
# Avg_Rating          object
# Review_Title        object
# Review_text         object
# Rating              object
# customer_city       object
# age_of_review       object
# review_upvotes      object
# review_downvotes    object
# dtype: object

# %%
df2.customer_city
# Out:
# 0                                 NaN
# 1                     Certified Buyer
# 2            Certified Buyer, Kolkata
# 3             Certified Buyer, Mumbai
# 4            Certified Buyer, Chennai
#                     ...
# 9985          Certified Buyer, Mumbai
# 9986          Certified Buyer, Mumbai
# 9987       Certified Buyer, Bengaluru
# 9988    Certified Buyer, Uppiliapuram
# 9989         Certified Buyer, Chennai
# Name: customer_city, Length: 9990, dtype: object

# %%
df2['customer_city']= df2['customer_city'].astype(str)

# %%
regex = ('[^,]*$')
df2['customer_city']=df2['customer_city'].apply(lambda x : re.compile(regex).findall(x))

# %%
df2.customer_city=df2.customer_city.apply(lambda x:str(x).replace('[','').replace(']',''))

# %%
df2.customer_city=df2.customer_city.apply(lambda x:str(x).replace("'",'').replace("'",''))

# %%
df2.customer_city=df2.customer_city.apply(lambda x:str(x).replace(',',''))

# %%
df2
# Out:
#      product_brand       product_name product_category product_price  \
# 0          samsung  samsung guru 1200           mobile          1334
# 1          samsung  samsung guru 1200           mobile          1334
# 2          samsung  samsung guru 1200           mobile          1334
# 3          samsung  samsung guru 1200           mobile          1334
# 4          samsung  samsung guru 1200           mobile          1334
# ...            ...                ...              ...           ...
# 9985       samsung  samsung guru 1200           mobile          1334
# 9986       samsung  samsung guru 1200           mobile          1334
# 9987       samsung  samsung guru 1200           mobile          1334
# 9988       samsung  samsung guru 1200           mobile          1334
# 9989       samsung  samsung guru 1200           mobile          1334
#
#                                        product_features Avg_Rating  \
# 0     [NA ROM3.81 cm (1.5 inch) NA Display800 mAh Ba...        4.3
# ...

# %%
df2.to_csv(r'samsungguru.csv',index=False)

# %%
concatenated_dataframes = pd.concat([df1, df2], axis=0)
concatenated_dataframes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-f81599bacaf4> in <module>
# ----> 1 concatenated_dataframes = pd.concat([df1, df2], axis=0)
#       2 concatenated_dataframes
#
# NameError: name 'df1' is not defined

# %%
a = []
b= []
c = []
d = []
e = []
f = []
g = []
h = []
ia = []
j = []
k = []
l = []
m = []
z = []
fe = []

# %%
feature = []
url = 'https://www.flipkart.com/search?q=realme+7&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_2_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_2_4_na_na_na&as-pos=2&as-type=RECENT&suggestionId=realme+7%7CMobiles&requestId=f1c98601-8afc-48fe-94fd-90a1e6ea0f49&as-searchtext=real'
page = requests.get(url)
htmlcode = page.text
soup = BeautifulSoup(htmlcode)
name = soup.find('div', attrs={'class' : 'fMghEO'})
feature.append(name.text)

# %%
df3= pd.read_csv(r'C:\Users\user\Documents\offlineclass\realme7.csv')
df3
# Out:
#      product_brand product_name product_category  product_price  \
# 0          Realme      Realme 7           mobile          14999
# 1          Realme      Realme 7           mobile          14999
# 2          Realme      Realme 7           mobile          14999
# 3          Realme      Realme 7           mobile          14999
# 4          Realme      Realme 7           mobile          14999
# ...            ...          ...              ...            ...
# 9784       Realme      Realme 7           mobile          14999
# 9785       Realme      Realme 7           mobile          14999
# 9786       Realme      Realme 7           mobile          14999
# 9787       Realme      Realme 7           mobile          14999
# 9788       Realme      Realme 7           mobile          14999
#
#                                        product_features  Avg_Rating  \
# 0     ['6 GB RAM | 64 GB ROM | Expandable Upto 256 G...         4.3
# ...

# %%
df4= pd.read_csv(r'C:\Users\user\Documents\offlineclass\samsungguru.csv')
df4
# Out:
#      product_brand       product_name product_category  product_price  \
# 0          samsung  samsung guru 1200           mobile           1334
# 1          samsung  samsung guru 1200           mobile           1334
# 2          samsung  samsung guru 1200           mobile           1334
# 3          samsung  samsung guru 1200           mobile           1334
# 4          samsung  samsung guru 1200           mobile           1334
# ...            ...                ...              ...            ...
# 9985       samsung  samsung guru 1200           mobile           1334
# 9986       samsung  samsung guru 1200           mobile           1334
# 9987       samsung  samsung guru 1200           mobile           1334
# 9988       samsung  samsung guru 1200           mobile           1334
# 9989       samsung  samsung guru 1200           mobile           1334
#
#                                        product_features  Avg_Rating  \
# ...

# %%
df5= pd.read_csv(r'C:\Users\user\Documents\offlineclass\lenovo_acer.csv')
df5
# Out:
#      product_brand                              product_name product_category  \
# 0             Acer  Acer Predator Helios 300 Core i5 7th Gen           Laptop
# 1             Acer  Acer Predator Helios 300 Core i5 7th Gen           Laptop
# 2             Acer  Acer Predator Helios 300 Core i5 7th Gen           Laptop
# 3             Acer  Acer Predator Helios 300 Core i5 7th Gen           Laptop
# 4             Acer  Acer Predator Helios 300 Core i5 7th Gen           Laptop
# ...            ...                                       ...              ...
# 1191        Lenovo       Lenovo Ideapad S145 Core i3 7th Gen           Laptop
# 1192        Lenovo       Lenovo Ideapad S145 Core i3 7th Gen           Laptop
# 1193        Lenovo       Lenovo Ideapad S145 Core i3 7th Gen           Laptop
# 1194        Lenovo       Lenovo Ideapad S145 Core i3 7th Gen           Laptop
# 1195        Lenovo       Lenovo Ideapad S145 Core i3 7th Gen           Laptop
#
# ...

# %%
AppleIphone6
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-c9e0f0a1c90c> in <module>
# ----> 1 AppleIphone6
#
# NameError: name 'AppleIphone6' is not defined

# %%
df6= pd.read_csv(r'C:\Users\user\Documents\offlineclass\AppleIphone6.csv')
df6

# %%
realmeNarzo10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-921ac0bd37f3> in <module>
# ----> 1 realmeNarzo10
#
# NameError: name 'realmeNarzo10' is not defined

# %%
df7= pd.read_csv(r'C:\Users\user\Documents\offlineclass\realmeNarzo10.csv')
df7
# Out:
#      product_brand     product_name product_category product_price  \
# 0          Realme   Realme Narzo 10           mobile        11,999
# 1          Realme   Realme Narzo 10           mobile        11,999
# 2          Realme   Realme Narzo 10           mobile        11,999
# 3          Realme   Realme Narzo 10           mobile        11,999
# 4          Realme   Realme Narzo 10           mobile        11,999
# ...            ...              ...              ...           ...
# 9955       Realme   Realme Narzo 10           mobile        11,999
# 9956       Realme   Realme Narzo 10           mobile        11,999
# 9957       Realme   Realme Narzo 10           mobile        11,999
# 9958       Realme   Realme Narzo 10           mobile        11,999
# 9959       Realme   Realme Narzo 10           mobile        11,999
#
#                                        product_features  Avg_Rating  \
# 0     ['4 GB RAM | 128 GB ROM | Expandable Upto 256 ...         4.5
# ...

# %%
df8= pd.read_csv(r'C:\Users\user\Documents\offlineclass\AsusZenfoneMax.csv')
df8
# Out:
#      product_brand      product_name product_category  product_price  \
# 0             Asus  Asus Zenfone Max           mobile           9999
# 1             Asus  Asus Zenfone Max           mobile           9999
# 2             Asus  Asus Zenfone Max           mobile           9999
# 3             Asus  Asus Zenfone Max           mobile           9999
# 4             Asus  Asus Zenfone Max           mobile           9999
# ...            ...               ...              ...            ...
# 9972          Asus  Asus Zenfone Max           mobile           9999
# 9973          Asus  Asus Zenfone Max           mobile           9999
# 9974          Asus  Asus Zenfone Max           mobile           9999
# 9975          Asus  Asus Zenfone Max           mobile           9999
# 9976          Asus  Asus Zenfone Max           mobile           9999
#
#                                        product_features  Avg_Rating  \
# 0     ['3 GB RAM | 32 GB ROM | Expandable Upto 256 G...         4.1
# ...

# %%
fldf = pd.concat([df3, df4,df5,df1,df7,df8], axis=0)
fldf
# Out:
#      product_brand      product_name product_category product_price  \
# 0          Realme           Realme 7           mobile         14999
# 1          Realme           Realme 7           mobile         14999
# 2          Realme           Realme 7           mobile         14999
# 3          Realme           Realme 7           mobile         14999
# 4          Realme           Realme 7           mobile         14999
# ...            ...               ...              ...           ...
# 9972          Asus  Asus Zenfone Max           mobile          9999
# 9973          Asus  Asus Zenfone Max           mobile          9999
# 9974          Asus  Asus Zenfone Max           mobile          9999
# 9975          Asus  Asus Zenfone Max           mobile          9999
# 9976          Asus  Asus Zenfone Max           mobile          9999
#
#                                        product_features Avg_Rating  \
# 0     ['6 GB RAM | 64 GB ROM | Expandable Upto 256 G...        4.3
# ...

# %%
CUs=[]
for i in fldf['customer_city']:
    if (i=='Certified Buyer '):
        CUs.append('NaN')
    else:
        CUs.append(i)

# %%
fldf['customer_city']=np.array(CUs)
fldf['customer_city']
# Out:
# 0                  Kollam
# 1               Ghaziabad
# 2                 Patulia
# 3               Ambikapur
# 4        Khammam District
#                ...
# 9972              Chennai
# 9973        Cuttack Sadar
# 9974           Coimbatore
# 9975              Chittor
# 9976            Ahmedabad
# Name: customer_city, Length: 50798, dtype: object

# %%
fldf.isnull().sum()
# Out:
# product_brand          0
# product_name           0
# product_category       0
# product_price          0
# product_features       0
# Avg_Rating             0
# Review_Title           0
# Review_text            0
# Rating              4829
# customer_city          0
# age_of_review          0
# review_upvotes         0
# review_downvotes       0
# dtype: int64

# %%
fldf['customer_city'].value_counts()
# Out:
# NaN               3374
#  New Delhi        2123
#  Hyderabad        1237
#  Bengaluru         939
#  Chennai           856
#                   ...
#  Vissannapet         1
#  Huzurnagar          1
#  Titagarh            1
#  Chendrappini        1
#  Gariaband           1
# Name: customer_city, Length: 4892, dtype: int64

# %%
fldf['age_of_review'].value_counts()
# Out:
# 3monthsago     9381
# 2monthsago     4292
# 1monthago      4145
# 4monthsago     3359
# 5monthsago     2706
#                ...
# aug2012           1
# sep2012           1
# 317daysago        1
# jul2012           1
# 63monthsago       1
# Name: age_of_review, Length: 155, dtype: int64

# %%
fldf.to_csv(r'finalflipkart_data7.csv',index=False)
